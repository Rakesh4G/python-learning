# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakesh4G/python-learning/blob/main/colab_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10*np.pi, 100)
y = np.sin(x)
plt.plot(x,y)

# %%
import seaborn
seaborn.__version__
# Out:
# '0.11.0'
